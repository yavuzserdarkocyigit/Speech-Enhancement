# %%
# %pip install datasets
# %pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # A) TIMIT

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/TIMIT_ver110train_0001.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # C.a) 0 dB NOISE ADDED TO TIMIT

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/noisy_newW.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # D) SPECTRAL SUBTRACTION USED ON NOISY TIMIT

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/my_enhanced.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # D) SpeechBrain ENHANCED NOISY TIMIT

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/sp_enhanced.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_v', 'wav2vec2.encoder.pos_conv_embed.conv.weight_g']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # E) 10th ORDER TIMIT REGENERATED

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/timit_gen10.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_v', 'wav2vec2.encoder.pos_conv_embed.conv.weight_g']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # E) 18TH ORDER TIMIT REGENERATED

# %%
 from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
 from datasets import load_dataset
 import torch
 import soundfile as sf

 # load model and tokenizer
 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# load your own audio file
audio_input, sample_rate = sf.read("/content/timit_gen18.wav")

# process your audio file
input_values = processor(audio_input, sampling_rate=sample_rate, return_tensors="pt", padding="longest").input_values

# retrieve logits
logits = model(input_values).logits

# take argmax and decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)

print(transcription)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_v', 'wav2vec2.encoder.pos_conv_embed.conv.weight_g']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import torch.nn.functional as F

# Apply softmax to convert logits to probabilities
probabilities = F.softmax(logits, dim=1).detach().squeeze()

print(probabilities)
probabilities.shape
# Out:
# tensor([[1.7016e-02, 6.1717e-06, 7.7303e-06,  ..., 9.1007e-04, 8.8693e-04,
#          1.0345e-03],
#         [3.3586e-02, 5.2761e-06, 7.0525e-06,  ..., 7.0042e-04, 5.4915e-04,
#          1.1054e-03],
#         [2.7925e-02, 5.7836e-06, 7.6501e-06,  ..., 7.6312e-04, 6.3796e-04,
#          1.1066e-03],
#         ...,
#         [1.6141e-02, 1.0540e-05, 1.3865e-05,  ..., 8.2921e-04, 4.7224e-04,
#          1.8301e-03],
#         [2.0963e-02, 9.6221e-06, 1.2777e-05,  ..., 8.4850e-04, 5.0283e-04,
#          1.5684e-03],
#         [1.7680e-02, 9.7736e-06, 1.2888e-05,  ..., 8.1503e-04, 4.7950e-04,
#          1.5686e-03]])
# torch.Size([198, 32])

# %% [markdown]
# # B) TIMIT SOLUTION - A/B/C PROBABILITIES

# %%
# Your vocabulary dictionary
vocab = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3, "|": 4, "E": 5, "T": 6, "A": 7, "O": 8, "N": 9, "I": 10, "H": 11, "S": 12, "R": 13, "D": 14, "L": 15, "U": 16, "M": 17, "W": 18, "C": 19, "F": 20, "G": 21, "Y": 22, "P": 23, "B": 24, "V": 25, "K": 26, "'": 27, "X": 28, "J": 29, "Q": 30, "Z": 31}
# Token IDs for 'A', 'B', and 'C'
token_id_a = vocab['A']
token_id_b = vocab['B']
token_id_c = vocab['C']

# Extract probabilities for these letters at frame 100
# Note: Indexing is zero-based, so frame 100 is at index 99
probability_a = probabilities[149, token_id_a]
probability_b = probabilities[149, token_id_b]
probability_c = probabilities[149, token_id_c]

print(f"Probability of 'A' at frame 150: {probability_a}")
print(f"Probability of 'B' at frame 150: {probability_b}")
print(f"Probability of 'C' at frame 150: {probability_c}")
# Out:
# Probability of 'A' at frame 150: 1.7448905055061914e-05
# Probability of 'B' at frame 150: 3.940751412301324e-05
# Probability of 'C' at frame 150: 5.7590168580645695e-06

# %% [markdown]
# # C.b) 0 dB NOISE ADDED TO TIMIT- A/B/C PROBABILITIES

# %%
# Your vocabulary dictionary
vocab = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3, "|": 4, "E": 5, "T": 6, "A": 7, "O": 8, "N": 9, "I": 10, "H": 11, "S": 12, "R": 13, "D": 14, "L": 15, "U": 16, "M": 17, "W": 18, "C": 19, "F": 20, "G": 21, "Y": 22, "P": 23, "B": 24, "V": 25, "K": 26, "'": 27, "X": 28, "J": 29, "Q": 30, "Z": 31}
# Token IDs for 'A', 'B', and 'C'
token_id_a = vocab['A']
token_id_b = vocab['B']
token_id_c = vocab['C']

# Extract probabilities for these letters at frame 100
# Note: Indexing is zero-based, so frame 100 is at index 99
probability_a = probabilities[149, token_id_a]
probability_b = probabilities[149, token_id_b]
probability_c = probabilities[149, token_id_c]

print(f"Probability of 'A' at frame 150: {probability_a}")
print(f"Probability of 'B' at frame 150: {probability_b}")
print(f"Probability of 'C' at frame 150: {probability_c}")
# Out:
# Probability of 'A' at frame 150: 0.00024504007888026536
# Probability of 'B' at frame 150: 0.0003947536461055279
# Probability of 'C' at frame 150: 0.015506522729992867

# %%
import plotly.graph_objects as go

# Your vocabulary dictionary
vocab = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3, "|": 4, "E": 5, "T": 6, "A": 7, "O": 8, "N": 9, "I": 10, "H": 11, "S": 12, "R": 13, "D": 14, "L": 15, "U": 16, "M": 17, "W": 18, "C": 19, "F": 20, "G": 21, "Y": 22, "P": 23, "B": 24, "V": 25, "K": 26, "'": 27, "X": 28, "J": 29, "Q": 30, "Z": 31}

# Assuming 'probabilities' is a numpy array or similar structure
# Replace 'probabilities' with your actual data variable

# Create heatmap
fig = go.Figure(data=go.Heatmap(
    z=probabilities.T,
    x=list(range(probabilities.shape[1])),
    y=list(vocab.keys()),
    colorscale='Viridis'  # Or any other color scale
))

# Update layout for better readability and add white gridlines
fig.update_layout(
    title='Interactive Heatmap with White Gridlines',
    xaxis_title='X-axis',
    yaxis_title='Vocabulary Keys',
    xaxis_showgrid=True,
    yaxis_showgrid=True,
    xaxis_gridcolor='white',
    yaxis_gridcolor='white',
    plot_bgcolor='rgba(0,0,0,0)'  # Makes background transparent
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# %pip install scipy

# %%
import scipy.io

# Save in a .mat file
scipy.io.savemat('tensor_data.mat', {'data': probabilities.detach().numpy()})

# %%
from IPython.display import Audio

# Assuming the name of your file is 'your-audio-file.mp3'
#audio_file = ds[0]["audio"]["path"]

audio_file = "/content/output (6).wav"

# Play the audio file
Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
